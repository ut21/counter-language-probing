# %%
import torch
from torch import nn
from torch.utils.data import DataLoader, TensorDataset
import numpy as np
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
# %load_ext autoreload
# %autoreload 2

from src.utils.helper import *
import pickle

with open('/Users/utkarsh/Documents/neural-toc/naacl_work/aviral_transformer_formal_language/models/shuffle4/vocab.p', 'rb') as f:
    vocab = pickle.load(f)
    
with open('/Users/utkarsh/Documents/neural-toc/naacl_work/aviral_transformer_formal_language/models/shuffle4/config.p', 'rb') as f:
    config = pickle.load(f)

# %%
from src.dataloader import *

data_path = '/Users/utkarsh/Documents/neural-toc/naacl_work/aviral_transformer_formal_language/data/Shuffle-4/train_corpus.pk'
with open(data_path, 'rb') as f:
    train_corpus = pickle.load(f)
    
train_loader = Sampler(train_corpus, vocab, 8)

src, _, wd_lens = train_loader.get_batch(0)
src.shape, wd_lens
# Out:
# ['(())', '{}', '(((<>)))', '[<()>]', '[]', '[((({})<>)()[[<[]>]])<><>[{<>}]]', '(<<<(<<([]){}{([{}])}[]>>)>>>)[]<[]>', '[[<()>]]']
# (torch.Size([36, 8]), tensor([ 4,  2,  8,  6,  2, 32, 36,  8]))

# %%
def pad_seq(seq, max_length, voc):
    seq += [voc.get_id('T') for i in range(max_length - len(seq))]
    return seq

def sent_to_idx(voc, sent, max_length=-1):
    idx_vec = []
    for w in sent:
        idx = voc.get_id(w)
        idx_vec.append(idx)

    idx_vec.append(voc.get_id('T'))
    idx_vec = pad_seq(idx_vec, max_length+1, voc)
    return idx_vec

def sents_to_idx(voc, sents):
    max_length = max([len(s) for s in sents])
    all_indexes = []
    for sent in sents:
        all_indexes.append(sent_to_idx(voc, sent, max_length))

    all_indexes = torch.tensor(all_indexes, dtype= torch.long)
    return all_indexes

raw = train_corpus.source
data_ids = sents_to_idx(vocab, raw)
data = data_ids[:, :-1]
data.shape
# Out:
# torch.Size([10000, 100])

# %%
OPEN_CURLY = vocab.get_id('{')
CLOSE_CURLY = vocab.get_id('}')
OPEN_ROUND = vocab.get_id('(')
CLOSE_ROUND = vocab.get_id(')')
OPEN_SQUARE = vocab.get_id('[')
CLOSE_SQUARE = vocab.get_id(']')
OPEN_ANGLE = vocab.get_id('<')
CLOSE_ANGLE = vocab.get_id('>')

print(OPEN_CURLY, CLOSE_CURLY, OPEN_ROUND, CLOSE_ROUND, OPEN_SQUARE, CLOSE_SQUARE, OPEN_ANGLE, CLOSE_ANGLE)

PAIRINGS = {
    OPEN_ROUND: CLOSE_ROUND,
    OPEN_CURLY: CLOSE_CURLY,
    OPEN_SQUARE: CLOSE_SQUARE,
    OPEN_ANGLE: CLOSE_ANGLE,
}

def simulate_stack(tokenised_paren):
    stack1 = []
    stack2 = []
    stack3 = []
    stack4 = []
    stack1_depths = []
    stack2_depths = []
    stack3_depths = []
    stack4_depths = []
    for token in tokenised_paren:
        token = token.item()
        if token == OPEN_ROUND:
            stack1.append(token)
        elif token == OPEN_CURLY:
            stack2.append(token)
        elif token == OPEN_SQUARE:
            stack3.append(token)
        elif token == OPEN_ANGLE:
            stack4.append(token)
        elif token == CLOSE_ROUND:
            if not stack1:
                raise ValueError("Unmatched curved closing bracket")
            stack1.pop()
        elif token == CLOSE_CURLY:
            if not stack2:
                raise ValueError("Unmatched square closing bracket")
            stack2.pop()
        elif token == CLOSE_SQUARE:
            if not stack3:
                raise ValueError("Unmatched square closing bracket")
            stack3.pop()
        elif token == CLOSE_ANGLE:
            if not stack4:
                raise ValueError("Unmatched square closing bracket")
            stack4.pop()
        stack1_depths.append(len(stack1))
        stack2_depths.append(len(stack2))
        stack3_depths.append(len(stack3))
        stack4_depths.append(len(stack4))
    if stack1 or stack2 or stack3 or stack4:
        raise ValueError("Unmatched opening brackets remain in stack")
    return stack1_depths, stack2_depths, stack3_depths, stack4_depths

def create_dataset(model, paren_tokens, device="cpu"):
    X = []
    Y = []

    model.eval()

    with torch.no_grad():
        for tokenised_paren in paren_tokens:
            output, internal = model.model(tokenised_paren.to(device).unsqueeze(0).T, get_encoder_reps=True)
            internal = internal.transpose(0, 1).squeeze(0)
            stack1_depths, stack2_depth, stack3_depth, stack4_depth = simulate_stack(tokenised_paren)
            for i, states in enumerate(internal):
                X.append(states.cpu().numpy())
                Y1.append(stack1_depths[i])
                Y2.append(stack2_depth[i])
                Y3.append(stack3_depth[i])
                Y4.append(stack4_depth[i])

    X_tensor = torch.tensor(X)
    Y1_tensor = torch.tensor(Y1)
    Y2_tensor = torch.tensor(Y2)
    Y3_tensor = torch.tensor(Y3)
    Y4_tensor = torch.tensor(Y4)
    
    return X_tensor, Y1_tensor, Y2_tensor, Y3_tensor, Y4_tensor
# Out:
# 3 8 6 7 2 1 5 4

# %%
import src
import torch
from src.model import LanguageModel
from src.components.transformers import TransformerModel

import torch

chkpt_path = '/Users/utkarsh/Documents/neural-toc/naacl_work/aviral_transformer_formal_language/models/shuffle4/model_25.pt'
model = LanguageModel(config, vocab, 'cpu', None)
model.load_state_dict(torch.load(chkpt_path, map_location='cpu')['model_state_dict'])
# Out:
# <All keys matched successfully>

# %%
class ProbingClassifier(nn.Module):
    def __init__(self, input_size, output_size, hidden_size=128):
        super(ProbingClassifier, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(0.2)
        self.fc2 = nn.Linear(hidden_size, hidden_size)
        self.fc3 = nn.Linear(hidden_size, hidden_size)
        self.fc4 = nn.Linear(hidden_size, output_size)
        
        nn.init.xavier_uniform_(self.fc1.weight)
        nn.init.xavier_uniform_(self.fc2.weight)
        nn.init.xavier_uniform_(self.fc3.weight)
        nn.init.xavier_uniform_(self.fc4.weight)

    def forward(self, x):
        out = self.fc1(x)
        out = self.relu(out)
        # out = self.dropout(out)
        # out = self.fc2(out)
        # out = self.relu(out)
        # out = self.dropout(out)
        # out = self.fc3(out)
        # out = self.relu(out)
        # out = self.dropout(out)
        out = self.fc4(out)
        return out

def create_dataset(model, paren_tokens, device="cpu"):
    X = []
    Y1 = []
    Y2 = []
    Y3 = []
    Y4 = []
    
    model.eval()
    
    with torch.no_grad():
        for tokenised_paren in paren_tokens:
            tokens = tokenised_paren.to(device).unsqueeze(0).T
            output, internal = model.model(tokens, get_encoder_reps=True)
            
            internal = internal.transpose(0, 1).squeeze(0)
            stack1_depths, stack2_depths, stack3_depths, stack4_depths = simulate_stack(tokenised_paren)
            
            for i, states in enumerate(internal):
                X.append(states.cpu().numpy())
                Y1.append(stack1_depths[i])
                Y2.append(stack2_depths[i])
                Y3.append(stack3_depths[i])
                Y4.append(stack4_depths[i])
    
    # Convert to numpy for normalization
    X = np.array(X)
    
    # Normalize features
    scaler = StandardScaler()
    X_normalized = scaler.fit_transform(X)
    
    X_tensor = torch.tensor(X_normalized, dtype=torch.float32)
    Y1_tensor = torch.tensor(Y1, dtype=torch.long)
    Y2_tensor = torch.tensor(Y2, dtype=torch.long)
    Y3_tensor = torch.tensor(Y3, dtype=torch.long)
    Y4_tensor = torch.tensor(Y4, dtype=torch.long)
    
    return X_tensor, Y1_tensor, Y2_tensor, Y3_tensor, Y4_tensor

def plot_accuracies(train_acc_orig, val_acc_orig, train_acc_random, val_acc_random):
    plt.figure(figsize=(10, 6))
    epochs = range(1, len(train_acc_orig) + 1)
    
    # Plot original task accuracies
    plt.plot(epochs, train_acc_orig, 'b-', label='Original Task - Train')
    plt.plot(epochs, val_acc_orig, 'b--', label='Original Task - Validation')
    
    # Plot random control task accuracies
    plt.plot(epochs, train_acc_random, 'r-', label='Random Control - Train')
    plt.plot(epochs, val_acc_random, 'r--', label='Random Control - Validation')
    
    plt.title('Probing Accuracy: Original vs Random Control')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)
    
    # Add chance level line
    num_classes = max(Y1.max().item(), Y_random.max().item()) + 1
    chance_level = 1.0 / num_classes
    plt.axhline(y=chance_level, color='g', linestyle='--', label=f'Chance Level ({chance_level:.3f})')
    
    plt.tight_layout()
    plt.show()

def train_probe(X, Y, model_name="original", num_epochs=10, batch_size=32, learning_rate=0.001):
    input_size = X.shape[1]
    num_classes = Y.max().item() + 1
    print(f"Input Size: {input_size}, Num Classes: {num_classes}")
    
    dataset = TensorDataset(X, Y)
    train_size = int(0.8 * len(dataset))
    val_size = len(dataset) - train_size
    train_dataset, val_dataset = torch.utils.data.random_split(dataset, [train_size, val_size])
    
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size)
    
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    probing_model = ProbingClassifier(input_size, num_classes).to(device)
    
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(probing_model.parameters(), lr=learning_rate)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=2)
    
    train_accuracies = []
    val_accuracies = []
    
    for epoch in range(num_epochs):
        # Training phase
        probing_model.train()
        train_correct = 0
        train_total = 0
        train_loss = 0
        
        for inputs, targets in train_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            
            optimizer.zero_grad()
            outputs = probing_model(inputs)
            loss = criterion(outputs, targets)
            loss.backward()
            optimizer.step()
            
            train_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            train_correct += (predicted == targets).sum().item()
            train_total += targets.size(0)
        
        # Validation phase
        probing_model.eval()
        val_correct = 0
        val_total = 0
        val_loss = 0
        
        with torch.no_grad():
            for inputs, targets in val_loader:
                inputs, targets = inputs.to(device), targets.to(device)
                outputs = probing_model(inputs)
                loss = criterion(outputs, targets)
                val_loss += loss.item()
                
                _, predicted = torch.max(outputs, 1)
                val_correct += (predicted == targets).sum().item()
                val_total += targets.size(0)
        
        train_accuracy = train_correct / train_total
        val_accuracy = val_correct / val_total
        avg_train_loss = train_loss / len(train_loader)
        avg_val_loss = val_loss / len(val_loader)
        
        train_accuracies.append(train_accuracy)
        val_accuracies.append(val_accuracy)
        
        scheduler.step(avg_val_loss)
        
        print(f"{model_name} - Epoch [{epoch+1}/{num_epochs}]")
        print(f"Train Loss: {avg_train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}")
        print(f"Val Loss: {avg_val_loss:.4f}, Val Accuracy: {val_accuracy:.4f}")
        print("-------------------")
    
    return train_accuracies, val_accuracies

# %%
X, Y1, Y2, Y3, Y4 = create_dataset(model, data, "cpu")

# Create a control dataset with randomized labels
Y_random = torch.randint_like(Y1, 0, Y1.max().item() + 1)

# Train both the original and control probes
original_train_acc, original_val_acc = train_probe(X, Y2, "Original")
random_train_acc, random_val_acc = train_probe(X, Y_random, "Control (Random)")

# Plot the results
plot_accuracies(original_train_acc, original_val_acc, random_train_acc, random_val_acc)
# Out:
# Input Size: 32, Num Classes: 13
# Original - Epoch [1/10]
# Train Loss: 0.2150, Train Accuracy: 0.9124
# Val Loss: 0.1970, Val Accuracy: 0.9192
# -------------------
# Original - Epoch [2/10]
# Train Loss: 0.1936, Train Accuracy: 0.9235
# Val Loss: 0.1867, Val Accuracy: 0.9292
# -------------------
# Original - Epoch [3/10]
# Train Loss: 0.1838, Train Accuracy: 0.9303
# Val Loss: 0.1761, Val Accuracy: 0.9342
# -------------------
# Original - Epoch [4/10]
# Train Loss: 0.1750, Train Accuracy: 0.9357
# Val Loss: 0.1689, Val Accuracy: 0.9389
# -------------------
# Original - Epoch [5/10]
# Train Loss: 0.1685, Train Accuracy: 0.9391
# Val Loss: 0.1669, Val Accuracy: 0.9388
# -------------------
# Original - Epoch [6/10]
# Train Loss: 0.1631, Train Accuracy: 0.9418
# Val Loss: 0.1588, Val Accuracy: 0.9428
# -------------------
# Original - Epoch [7/10]
# Train Loss: 0.1589, Train Accuracy: 0.9439
# Val Loss: 0.1538, Val Accuracy: 0.9479
# -------------------
# Original - Epoch [8/10]
# Train Loss: 0.1553, Train Accuracy: 0.9456
# Val Loss: 0.1488, Val Accuracy: 0.9494
# -------------------
# Original - Epoch [9/10]
# Train Loss: 0.1525, Train Accuracy: 0.9470
# Val Loss: 0.1608, Val Accuracy: 0.9408
# -------------------
# Original - Epoch [10/10]
# Train Loss: 0.1496, Train Accuracy: 0.9481
# Val Loss: 0.1495, Val Accuracy: 0.9474
# -------------------
# Input Size: 32, Num Classes: 14
# Control (Random) - Epoch [1/10]
# Train Loss: 2.6429, Train Accuracy: 0.0716
# Val Loss: 2.6398, Val Accuracy: 0.0723
# -------------------
# Control (Random) - Epoch [2/10]
# Train Loss: 2.6395, Train Accuracy: 0.0721
# Val Loss: 2.6392, Val Accuracy: 0.0713
# -------------------
# Control (Random) - Epoch [3/10]
# Train Loss: 2.6393, Train Accuracy: 0.0719
# Val Loss: 2.6394, Val Accuracy: 0.0720
# -------------------
# Control (Random) - Epoch [4/10]
# Train Loss: 2.6392, Train Accuracy: 0.0713
# Val Loss: 2.6393, Val Accuracy: 0.0712
# -------------------
# Control (Random) - Epoch [5/10]
# Train Loss: 2.6392, Train Accuracy: 0.0716
# Val Loss: 2.6391, Val Accuracy: 0.0707
# -------------------
# Control (Random) - Epoch [6/10]
# Train Loss: 2.6391, Train Accuracy: 0.0725
# Val Loss: 2.6391, Val Accuracy: 0.0724
# -------------------
# Control (Random) - Epoch [7/10]
# Train Loss: 2.6390, Train Accuracy: 0.0727
# Val Loss: 2.6391, Val Accuracy: 0.0725
# -------------------
# Control (Random) - Epoch [8/10]
# Train Loss: 2.6390, Train Accuracy: 0.0727
# Val Loss: 2.6391, Val Accuracy: 0.0725
# -------------------
# Control (Random) - Epoch [9/10]
# Train Loss: 2.6390, Train Accuracy: 0.0727
# Val Loss: 2.6391, Val Accuracy: 0.0724
# -------------------
# Control (Random) - Epoch [10/10]
# Train Loss: 2.6390, Train Accuracy: 0.0727
# Val Loss: 2.6391, Val Accuracy: 0.0725
# -------------------

# %%
class ProbingClassifierAblation(nn.Module):
    def __init__(self, input_size, output_size, hidden_size=128, n_layers=1):
        super(ProbingClassifierAblation, self).__init__()
        self.n_layers = n_layers
        self.linear = nn.Linear(input_size, output_size)
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(0.2)
        self.fc2 = nn.Linear(hidden_size, hidden_size)
        self.fc3 = nn.Linear(hidden_size, hidden_size)
        self.fc4 = nn.Linear(hidden_size, output_size)
        self.fc5 = nn.Linear(hidden_size, 256)
        self.fc6 = nn.Linear(256, output_size)
        self.fc7 = nn.Linear(256, hidden_size)
        self.fc8 = nn.Linear(256, 256)
        
        nn.init.xavier_uniform_(self.fc1.weight)
        nn.init.xavier_uniform_(self.fc2.weight)
        nn.init.xavier_uniform_(self.fc3.weight)
        nn.init.xavier_uniform_(self.fc4.weight)

    def forward(self, x):
        if self.n_layers == 0:
            out = self.linear(x)
        elif self.n_layers == 1:
            out = self.fc1(x)
            out = self.relu(out)
            out = self.fc4(out)
        elif self.n_layers == 2:
            out = self.fc1(x)
            out = self.relu(out)
            out = self.fc2(out)
            out = self.relu(out)
            out = self.fc4(out)
        elif self.n_layers == 3:
            out = self.fc1(x)
            out = self.relu(out)
            out = self.fc2(out)
            out = self.relu(out)
            out = self.fc3(out)
            out = self.relu(out)
            out = self.fc4(out)
        elif self.n_layers == 4:
            out = self.fc1(x)
            out = self.relu(out)
            out = self.fc2(out)
            out = self.relu(out)
            out = self.fc5(out)
            out = self.relu(out)
            out = self.fc8(out)
            out = self.relu(out)
            out = self.fc7(out)
            out = self.relu(out)
            out = self.fc4(out)
        return out
def train_probe_ablation(X, Y, model_name="original", num_epochs=10, batch_size=32, learning_rate=0.001, n_layers = 1):
    input_size = X.shape[1]
    num_classes = Y.max().item() + 1
    print(f"Input Size: {input_size}, Num Classes: {num_classes}")
    
    dataset = TensorDataset(X, Y)
    train_size = int(0.8 * len(dataset))
    val_size = len(dataset) - train_size
    train_dataset, val_dataset = torch.utils.data.random_split(dataset, [train_size, val_size])
    
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size)
    
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    probing_model = ProbingClassifierAblation(input_size, num_classes, n_layers=n_layers).to(device)
    
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(probing_model.parameters(), lr=learning_rate)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=2)
    
    train_accuracies = []
    val_accuracies = []
    
    for epoch in range(num_epochs):
        # Training phase
        probing_model.train()
        train_correct = 0
        train_total = 0
        train_loss = 0
        
        for inputs, targets in train_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            
            optimizer.zero_grad()
            outputs = probing_model(inputs)
            loss = criterion(outputs, targets)
            loss.backward()
            optimizer.step()
            
            train_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            train_correct += (predicted == targets).sum().item()
            train_total += targets.size(0)
        
        # Validation phase
        probing_model.eval()
        val_correct = 0
        val_total = 0
        val_loss = 0
        
        with torch.no_grad():
            for inputs, targets in val_loader:
                inputs, targets = inputs.to(device), targets.to(device)
                outputs = probing_model(inputs)
                loss = criterion(outputs, targets)
                val_loss += loss.item()
                
                _, predicted = torch.max(outputs, 1)
                val_correct += (predicted == targets).sum().item()
                val_total += targets.size(0)
        
        train_accuracy = train_correct / train_total
        val_accuracy = val_correct / val_total
        avg_train_loss = train_loss / len(train_loader)
        avg_val_loss = val_loss / len(val_loader)
        
        train_accuracies.append(train_accuracy)
        val_accuracies.append(val_accuracy)
        
        scheduler.step(avg_val_loss)
        
        print(f"{model_name} - Epoch [{epoch+1}/{num_epochs}]")
        print(f"Train Loss: {avg_train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}")
        print(f"Val Loss: {avg_val_loss:.4f}, Val Accuracy: {val_accuracy:.4f}")
        print("-------------------")
    
    return train_accuracies, val_accuracies

# %%
traintaskm0, valtaskm0 = train_probe_ablation(X, Y2, "Original", n_layers=0)
reainrandomm0, valrandomm0 = train_probe_ablation(X, Y_random, "Control (Random)", n_layers=0)
tm0 = max(traintaskm0)
vm0 = max(valtaskm0)
rm0 = max(reainrandomm0)
rv0 = max(valrandomm0)

traintaskm1, valtaskm1 = train_probe_ablation(X, Y2, "Original", n_layers=1)
trainrandomm1, valrandomm1 = train_probe_ablation(X, Y_random, "Control (Random)", n_layers=1)
tm1 = max(traintaskm1)
vm1 = max(valtaskm1)
rm1 = max(trainrandomm1)
rv1 = max(valrandomm1)

traintaskm2, valtaskm2 = train_probe_ablation(X, Y2, "Original", n_layers=2)
trainrandomm2, valrandomm2 = train_probe_ablation(X, Y_random, "Control (Random)", n_layers=2)
tm2 = max(traintaskm2)
vm2 = max(valtaskm2)
rm2 = max(trainrandomm2)
rv2 = max(valrandomm2)

traintaskm3, valtaskm3 = train_probe_ablation(X, Y2, "Original", n_layers=3)
trainrandomm3, valrandomm3 = train_probe_ablation(X, Y_random, "Control (Random)", n_layers=3)
tm3 = max(traintaskm3)
vm3 = max(valtaskm3)
rm3 = max(trainrandomm3)
rv3 = max(valrandomm3)

traintaskm4, valtaskm4 = train_probe_ablation(X, Y2, "Original", n_layers=4)
trainrandomm4, valrandomm4 = train_probe_ablation(X, Y_random, "Control (Random)", n_layers=4)
tm4 = max(traintaskm4)
vm4 = max(valtaskm4)
rm4 = max(trainrandomm4)
rv4 = max(valrandomm4)
# Out:
# Input Size: 32, Num Classes: 13
# Original - Epoch [1/10]
# Train Loss: 0.2796, Train Accuracy: 0.8975
# Val Loss: 0.2289, Val Accuracy: 0.9031
# -------------------
# Original - Epoch [2/10]
# Train Loss: 0.2262, Train Accuracy: 0.9053
# Val Loss: 0.2260, Val Accuracy: 0.9042
# -------------------
# Original - Epoch [3/10]
# Train Loss: 0.2236, Train Accuracy: 0.9058
# Val Loss: 0.2234, Val Accuracy: 0.9054
# -------------------
# Original - Epoch [4/10]
# Train Loss: 0.2224, Train Accuracy: 0.9059
# Val Loss: 0.2224, Val Accuracy: 0.9057
# -------------------
# Original - Epoch [5/10]
# Train Loss: 0.2218, Train Accuracy: 0.9060
# Val Loss: 0.2220, Val Accuracy: 0.9059
# -------------------
# Original - Epoch [6/10]
# Train Loss: 0.2213, Train Accuracy: 0.9063
# Val Loss: 0.2238, Val Accuracy: 0.9045
# -------------------
# Original - Epoch [7/10]
# Train Loss: 0.2210, Train Accuracy: 0.9065
# Val Loss: 0.2211, Val Accuracy: 0.9055
# -------------------
# Original - Epoch [8/10]
# Train Loss: 0.2208, Train Accuracy: 0.9066
# Val Loss: 0.2209, Val Accuracy: 0.9052
# -------------------
# Original - Epoch [9/10]
# Train Loss: 0.2206, Train Accuracy: 0.9068
# Val Loss: 0.2209, Val Accuracy: 0.9057
# -------------------
# Original - Epoch [10/10]
# Train Loss: 0.2203, Train Accuracy: 0.9070
# Val Loss: 0.2206, Val Accuracy: 0.9050
# -------------------
# Input Size: 32, Num Classes: 14
# Control (Random) - Epoch [1/10]
# Train Loss: 2.6456, Train Accuracy: 0.0712
# Val Loss: 2.6433, Val Accuracy: 0.0709
# -------------------
# Control (Random) - Epoch [2/10]
# Train Loss: 2.6444, Train Accuracy: 0.0714
# Val Loss: 2.6468, Val Accuracy: 0.0723
# -------------------
# Control (Random) - Epoch [3/10]
# Train Loss: 2.6445, Train Accuracy: 0.0715
# Val Loss: 2.6431, Val Accuracy: 0.0734
# -------------------
# Control (Random) - Epoch [4/10]
# Train Loss: 2.6443, Train Accuracy: 0.0716
# Val Loss: 2.6428, Val Accuracy: 0.0706
# -------------------
# Control (Random) - Epoch [5/10]
# Train Loss: 2.6443, Train Accuracy: 0.0717
# Val Loss: 2.6440, Val Accuracy: 0.0710
# -------------------
# Control (Random) - Epoch [6/10]
# Train Loss: 2.6442, Train Accuracy: 0.0721
# Val Loss: 2.6430, Val Accuracy: 0.0710
# -------------------
# Control (Random) - Epoch [7/10]
# Train Loss: 2.6443, Train Accuracy: 0.0714
# Val Loss: 2.6438, Val Accuracy: 0.0711
# -------------------
# Control (Random) - Epoch [8/10]
# Train Loss: 2.6397, Train Accuracy: 0.0720
# Val Loss: 2.6397, Val Accuracy: 0.0719
# -------------------
# Control (Random) - Epoch [9/10]
# Train Loss: 2.6395, Train Accuracy: 0.0718
# Val Loss: 2.6399, Val Accuracy: 0.0719
# -------------------
# Control (Random) - Epoch [10/10]
# Train Loss: 2.6395, Train Accuracy: 0.0720
# Val Loss: 2.6395, Val Accuracy: 0.0727
# -------------------
# Input Size: 32, Num Classes: 13
# Original - Epoch [1/10]
# Train Loss: 0.2140, Train Accuracy: 0.9125
# Val Loss: 0.1994, Val Accuracy: 0.9187
# -------------------
# Original - Epoch [2/10]
# Train Loss: 0.1912, Train Accuracy: 0.9264
# Val Loss: 0.1853, Val Accuracy: 0.9314
# -------------------
# Original - Epoch [3/10]
# Train Loss: 0.1798, Train Accuracy: 0.9335
# Val Loss: 0.1727, Val Accuracy: 0.9368
# -------------------
# Original - Epoch [4/10]
# Train Loss: 0.1715, Train Accuracy: 0.9380
# Val Loss: 0.1659, Val Accuracy: 0.9436
# -------------------
# Original - Epoch [5/10]
# Train Loss: 0.1648, Train Accuracy: 0.9413
# Val Loss: 0.1633, Val Accuracy: 0.9434
# -------------------
# Original - Epoch [6/10]
# Train Loss: 0.1591, Train Accuracy: 0.9437
# Val Loss: 0.1587, Val Accuracy: 0.9443
# -------------------
# Original - Epoch [7/10]
# Train Loss: 0.1544, Train Accuracy: 0.9457
# Val Loss: 0.1574, Val Accuracy: 0.9411
# -------------------
# Original - Epoch [8/10]
# Train Loss: 0.1509, Train Accuracy: 0.9471
# Val Loss: 0.1499, Val Accuracy: 0.9483
# -------------------
# Original - Epoch [9/10]
# Train Loss: 0.1479, Train Accuracy: 0.9482
# Val Loss: 0.1442, Val Accuracy: 0.9510
# -------------------
# Original - Epoch [10/10]
# Train Loss: 0.1453, Train Accuracy: 0.9494
# Val Loss: 0.1458, Val Accuracy: 0.9504
# -------------------
# Input Size: 32, Num Classes: 14
# Control (Random) - Epoch [1/10]
# Train Loss: 2.6431, Train Accuracy: 0.0714
# Val Loss: 2.6394, Val Accuracy: 0.0713
# -------------------
# Control (Random) - Epoch [2/10]
# Train Loss: 2.6395, Train Accuracy: 0.0720
# Val Loss: 2.6394, Val Accuracy: 0.0727
# -------------------
# Control (Random) - Epoch [3/10]
# Train Loss: 2.6393, Train Accuracy: 0.0718
# Val Loss: 2.6392, Val Accuracy: 0.0719
# -------------------
# Control (Random) - Epoch [4/10]
# Train Loss: 2.6392, Train Accuracy: 0.0717
# Val Loss: 2.6392, Val Accuracy: 0.0719
# -------------------
# Control (Random) - Epoch [5/10]
# Train Loss: 2.6391, Train Accuracy: 0.0724
# Val Loss: 2.6391, Val Accuracy: 0.0726
# -------------------
# Control (Random) - Epoch [6/10]
# Train Loss: 2.6391, Train Accuracy: 0.0725
# Val Loss: 2.6391, Val Accuracy: 0.0726
# -------------------
# Control (Random) - Epoch [7/10]
# Train Loss: 2.6391, Train Accuracy: 0.0727
# Val Loss: 2.6391, Val Accuracy: 0.0725
# -------------------
# Control (Random) - Epoch [8/10]
# Train Loss: 2.6391, Train Accuracy: 0.0724
# Val Loss: 2.6391, Val Accuracy: 0.0725
# -------------------

# %%
import matplotlib.pyplot as plt

# Define the lists
task_train = [tm0, tm1, tm2, tm3, tm4]
task_val = [vm0, vm1, vm2, vm3, vm4]
random_train = [rm0, rm1, rm2, rm3, rm4]
random_val = [rv0, rv1, rv2, rv3, rv4]

plt.figure(figsize=(10, 4))
# plt.plot(task_train, label='Task Train', marker='o')
plt.plot(task_val, label='Task Validation', marker='o')
# plt.plot(random_train, label='Random Train', marker='o')
plt.plot(random_val, label='Control Task Validation', marker='o')

# Add vertical lines between corresponding points of task_val and random_val
for i, (tv, rv) in enumerate(zip(task_val, random_val)):
    plt.vlines(x=i, ymin=tv, ymax=rv, colors='gray', linestyles='dashed')

for i, (tv, rv) in enumerate(zip(task_val, random_val)):
    plt.annotate(f'{tv:.3f}', (i, tv), textcoords="offset points", xytext=(0,-15), ha='center')
    plt.annotate(f'{rv:.3f}', (i, rv), textcoords="offset points", xytext=(0,7), ha='center')

# Add labels and title
plt.xlabel('Number of Layers with ReLU activation')
plt.ylabel('Accuracy')
plt.title('Shuffle-4 Probe')

# Add a legend
plt.legend()

# Set x-axis labels
plt.xticks([0, 1, 2, 3, 4], ['Linear', '2 layers', '3 layers', '4 layers', '6 layers'])
plt.savefig('shuffle4_stack2.png', dpi=300)
# Display the plot
plt.show()
